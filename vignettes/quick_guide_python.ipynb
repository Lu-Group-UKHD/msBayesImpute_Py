# %% [markdown]
# # A quick guide of using msBayesImpute for imputing missing values in mass-spectrometry proteomics/metabolomics data

# %% [markdown]
# MsBayesImpute is a method that combines Bayesian factorization models and probablistic dropout models for imputing missing values in mass-spectrometry proteomics data, accounting for the non-randomness of missing data points in MS data.
# MsBayesImpute is built upon the Pyro, a universal probabilistic programming language (PPL) written in Python.
# The required Python packages for running msBayesImpute are: **numpy** and **pandas** (for reading and writing csv files).

# %% [markdown]
# ## Install package

# %%
pip install ../dist/msbayesimputepy-0.1.0-py3-none-any.whl
# Out:
# Processing /Users/jiaojiaohe/Desktop/Project2 - Imputation/Factorization/msbayesimputepy/dist/msbayesimputepy-0.1.0-py3-none-any.whl
# Requirement already satisfied: pandas in /Users/jiaojiaohe/anaconda3/lib/python3.11/site-packages (from msbayesimputepy==0.1.0) (2.3.1)
# Requirement already satisfied: numpy==1.26.2 in /Users/jiaojiaohe/anaconda3/lib/python3.11/site-packages (from msbayesimputepy==0.1.0) (1.26.2)
# Requirement already satisfied: torch in /Users/jiaojiaohe/anaconda3/lib/python3.11/site-packages (from msbayesimputepy==0.1.0) (2.7.1)
# Requirement already satisfied: pyro-ppl>=1.9.0 in /Users/jiaojiaohe/anaconda3/lib/python3.11/site-packages (from msbayesimputepy==0.1.0) (1.9.1)
# Requirement already satisfied: scikit-learn in /Users/jiaojiaohe/anaconda3/lib/python3.11/site-packages (from msbayesimputepy==0.1.0) (1.7.1)
# Requirement already satisfied: scipy in /Users/jiaojiaohe/anaconda3/lib/python3.11/site-packages (from msbayesimputepy==0.1.0) (1.16.1)
# Requirement already satisfied: seaborn in /Users/jiaojiaohe/anaconda3/lib/python3.11/site-packages (from msbayesimputepy==0.1.0) (0.13.2)
# Requirement already satisfied: matplotlib in /Users/jiaojiaohe/anaconda3/lib/python3.11/site-packages (from msbayesimputepy==0.1.0) (3.10.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/jiaojiaohe/anaconda3/lib/python3.11/site-packages (from pyro-ppl>=1.9.0->msbayesimputepy==0.1.0) (3.4.0)
# Requirement already satisfied: pyro-api>=0.1.1 in /Users/jiaojiaohe/anaconda3/lib/python3.11/site-packages (from pyro-ppl>=1.9.0->msbayesimputepy==0.1.0) (0.1.2)
# Requirement already satisfied: tqdm>=4.36 in /Users/jiaojiaohe/anaconda3/lib/python3.11/site-packages (from pyro-ppl>=1.9.0->msbayesimputepy==0.1.0) (4.67.1)
# Requirement already satisfied: filelock in /Users/jiaojiaohe/anaconda3/lib/python3.11/site-packages (from torch->msbayesimputepy==0.1.0) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/jiaojiaohe/anaconda3/lib/python3.11/site-packages (from torch->msbayesimputepy==0.1.0) (4.14.1)
# Requirement already satisfied: sympy>=1.13.3 in /Users/jiaojiaohe/anaconda3/lib/python3.11/site-packages (from torch->msbayesimputepy==0.1.0) (1.14.0)
# Requirement already satisfied: networkx in /Users/jiaojiaohe/anaconda3/lib/python3.11/site-packages (from torch->msbayesimputepy==0.1.0) (3.5)
# Requirement already satisfied: jinja2 in /Users/jiaojiaohe/anaconda3/lib/python3.11/site-packages (from torch->msbayesimputepy==0.1.0) (3.1.6)
# Requirement already satisfied: fsspec in /Users/jiaojiaohe/anaconda3/lib/python3.11/site-packages (from torch->msbayesimputepy==0.1.0) (2025.7.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/jiaojiaohe/anaconda3/lib/python3.11/site-packages (from matplotlib->msbayesimputepy==0.1.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/jiaojiaohe/anaconda3/lib/python3.11/site-packages (from matplotlib->msbayesimputepy==0.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/jiaojiaohe/anaconda3/lib/python3.11/site-packages (from matplotlib->msbayesimputepy==0.1.0) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/jiaojiaohe/anaconda3/lib/python3.11/site-packages (from matplotlib->msbayesimputepy==0.1.0) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/jiaojiaohe/anaconda3/lib/python3.11/site-packages (from matplotlib->msbayesimputepy==0.1.0) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/jiaojiaohe/anaconda3/lib/python3.11/site-packages (from matplotlib->msbayesimputepy==0.1.0) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/jiaojiaohe/anaconda3/lib/python3.11/site-packages (from matplotlib->msbayesimputepy==0.1.0) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/jiaojiaohe/anaconda3/lib/python3.11/site-packages (from matplotlib->msbayesimputepy==0.1.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/jiaojiaohe/anaconda3/lib/python3.11/site-packages (from pandas->msbayesimputepy==0.1.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/jiaojiaohe/anaconda3/lib/python3.11/site-packages (from pandas->msbayesimputepy==0.1.0) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /Users/jiaojiaohe/anaconda3/lib/python3.11/site-packages (from scikit-learn->msbayesimputepy==0.1.0) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/jiaojiaohe/anaconda3/lib/python3.11/site-packages (from scikit-learn->msbayesimputepy==0.1.0) (3.6.0)
# Requirement already satisfied: six>=1.5 in /Users/jiaojiaohe/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->msbayesimputepy==0.1.0) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/jiaojiaohe/anaconda3/lib/python3.11/site-packages (from sympy>=1.13.3->torch->msbayesimputepy==0.1.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/jiaojiaohe/anaconda3/lib/python3.11/site-packages (from jinja2->torch->msbayesimputepy==0.1.0) (3.0.2)
# Installing collected packages: msbayesimputepy
# Successfully installed msbayesimputepy-0.1.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Import required packages

# %%
from msbayesimputepy.generation import gen_data, gen_prob_miss
from msbayesimputepy.core import msBayesImpute
import numpy as np
import pandas as pd

# %% [markdown]
# ## Generate data with artificial missing values

# %% [markdown]
# - The complete data is generated by defining protein size (D), sample size (N) and latent factor (K) and protein intercept (feature_inter).
# - Missing values are created by a probabilistic dropout distribution characterized by inflection and scale parameters.

# %%
# generate data
np.random.seed(202411)
D = 5000
N = 200
K = 10
feature_inter = 20
ratio = 0.1
generation = gen_data(n_features = D, n_samples = N, n_factors = K, alpha_col = feature_inter)
generate_data = generation["data"]

# %%
# generate missings
simuData = gen_prob_miss(generate_data, rho = 17.5, zeta = 2, rho_sd = 2, zeta_sd = 1, model = "perFeature")
simuData["X_miss"]
# Out:
#               sample_1  sample_2  sample_3  sample_4  sample_5  sample_6  \
# feature_1          NaN       NaN       NaN       NaN       NaN       NaN
# feature_2     21.35771  18.15361  25.70704  16.94694  20.50456  24.48452
# feature_3     21.27044       NaN       NaN  15.46760  13.54686  25.59514
# feature_4          NaN       NaN  20.70437  20.01081  23.54113       NaN
# feature_5     19.24773  19.72803  24.08629       NaN       NaN  26.66391
# ...                ...       ...       ...       ...       ...       ...
# feature_4996       NaN       NaN  19.60327  21.05771  19.93693  22.27992
# feature_4997       NaN  22.32774  25.81730  19.30176       NaN  24.40884
# feature_4998  22.44802  21.05945  20.06088  22.95352  21.75321       NaN
# feature_4999       NaN  22.63368  24.66836  22.98442  17.88588  24.81728
# feature_5000  17.52332  20.08652  21.57204       NaN       NaN  25.14960
#
#               sample_7  sample_8  sample_9  sample_10  ...  sample_191  \
# feature_1     17.30993       NaN  19.36536        NaN  ...         NaN
# feature_2     21.99810  22.63902  25.21135   21.02091  ...    27.28163
# feature_3     20.41242       NaN  22.90487   18.25608  ...    24.31340
# feature_4     23.70579       NaN       NaN   20.37735  ...    19.97506
# feature_5     20.33935  17.18838  24.08511   23.71116  ...    25.31210
# ...                ...       ...       ...        ...  ...         ...
# feature_4996  20.48328  20.83228  20.71718   19.82733  ...    23.72726
# feature_4997  21.64394  20.78337  23.04999        NaN  ...         NaN
# feature_4998  20.05362       NaN  22.30025   25.25971  ...         NaN
# feature_4999  16.86489  23.40688  19.94300   18.62826  ...    26.30401
# feature_5000       NaN  20.68131  18.54044   21.69730  ...    27.44359
#
#               sample_192  sample_193  sample_194  sample_195  sample_196  \
# feature_1       23.28569         NaN         NaN         NaN         NaN
# feature_2       26.39487    20.52996         NaN         NaN    24.08542
# feature_3       25.65968         NaN    19.79213         NaN    23.21405
# feature_4       21.75430         NaN    22.94145    21.23125    20.16064
# feature_5       24.71970    19.46055    27.40503         NaN    26.30030
# ...                  ...         ...         ...         ...         ...
# feature_4996    22.78724         NaN    19.25925    18.15226         NaN
# feature_4997         NaN    19.71806    26.14963    21.62542    21.28454
# feature_4998         NaN         NaN    23.82556    25.43966    23.65458
# feature_4999    18.09135    26.18410    30.52415    22.66261         NaN
# feature_5000    16.63212    23.50594    21.21203         NaN    22.89749
#
#               sample_197  sample_198  sample_199  sample_200
# feature_1            NaN         NaN         NaN         NaN
# feature_2       26.66449    20.79465    20.65267         NaN
# feature_3       22.11616    20.80227    22.55273         NaN
# feature_4            NaN    23.32555         NaN         NaN
# feature_5       25.52853    20.54043         NaN         NaN
# ...                  ...         ...         ...         ...
# feature_4996         NaN         NaN         NaN         NaN
# feature_4997    21.17954    24.10425    21.73265         NaN
# feature_4998         NaN    26.92724         NaN         NaN
# feature_4999    23.26888    16.76908    19.38203    21.79644
# feature_5000    22.96790         NaN    19.30234    24.82458
#
# [5000 rows x 200 columns]

# %% [markdown]
# ## Read example dataset

# %% [markdown]
# Prior to running the model, certain data preprocessing steps are required:
# 1. Remove completely missing proteins/metabolites
# 2. Ensure the dataset follows a normal distribution, such as by applying a log transformation to the raw data.

# %%
#read in data as dataframe
df = pd.read_csv('../data/hela_proteomics_example.csv', delimiter = ",", index_col = 0)
df
# Out:
#                   X2019_12_18_14_35_Q.Exactive.HF.X.Orbitrap_6070  \
# AAAS                                                    28.349295
# AACS                                                    26.133163
# AAMDC                                                         NaN
# AAMP                                                    26.776933
# AAR2                                                    27.247805
# ...                                                           ...
# ZWILCH                                                        NaN
# ZWINT                                                   24.379346
# ZYX                                                     29.427124
# hCG_2014768.TMA7                                        28.079689
# pk.ZAK                                                  22.879160
#
#                   X2019_12_19_19_48_Q.Exactive.HF.X.Orbitrap_6070  \
# AAAS                                                    27.657378
# AACS                                                    25.018649
# AAMDC                                                   24.236226
# AAMP                                                    26.270706
# AAR2                                                    27.210668
# ...                                                           ...
# ZWILCH                                                        NaN
# ZWINT                                                         NaN
# ZYX                                                     28.080503
# hCG_2014768.TMA7                                              NaN
# pk.ZAK                                                        NaN
#
#                   X2019_12_20_14_15_Q.Exactive.HF.X.Orbitrap_6070  \
# AAAS                                                    28.352160
# AACS                                                    23.740468
# AAMDC                                                         NaN
# AAMP                                                    27.097882
# AAR2                                                    27.377411
# ...                                                           ...
# ZWILCH                                                        NaN
# ZWINT                                                   25.802919
# ZYX                                                     29.525072
# hCG_2014768.TMA7                                              NaN
# pk.ZAK                                                        NaN
#
#                   X2019_12_27_12_29_Q.Exactive.HF.X.Orbitrap_6070  \
# AAAS                                                    26.825537
# AACS                                                          NaN
# AAMDC                                                         NaN
# AAMP                                                    26.256343
# AAR2                                                          NaN
# ...                                                           ...
# ZWILCH                                                        NaN
# ZWINT                                                   24.687685
# ZYX                                                     28.783224
# hCG_2014768.TMA7                                              NaN
# pk.ZAK                                                        NaN
#
#                   X2019_12_29_15_06_Q.Exactive.HF.X.Orbitrap_6070  \
# AAAS                                                    27.403650
# AACS                                                    26.948488
# AAMDC                                                   23.864386
# AAMP                                                    26.981635
# AAR2                                                    26.519788
# ...                                                           ...
# ZWILCH                                                  26.406378
# ZWINT                                                         NaN
# ZYX                                                     30.422219
# hCG_2014768.TMA7                                              NaN
# pk.ZAK                                                  26.939100
#
#                   X2019_12_29_18_18_Q.Exactive.HF.X.Orbitrap_6070  \
# AAAS                                                    27.891281
# AACS                                                    26.481022
# AAMDC                                                   26.347547
# AAMP                                                    27.849418
# AAR2                                                    26.916955
# ...                                                           ...
# ZWILCH                                                  26.037330
# ZWINT                                                   25.002430
# ZYX                                                     30.928183
# hCG_2014768.TMA7                                              NaN
# pk.ZAK                                                  27.088006
#
#                   X2020_01_02_17_38_Q.Exactive.HF.X.Orbitrap_6070  \
# AAAS                                                    25.498262
# AACS                                                          NaN
# AAMDC                                                         NaN
# AAMP                                                          NaN
# AAR2                                                          NaN
# ...                                                           ...
# ZWILCH                                                        NaN
# ZWINT                                                         NaN
# ZYX                                                     28.465093
# hCG_2014768.TMA7                                        28.902336
# pk.ZAK                                                        NaN
#
#                   X2020_01_03_11_17_Q.Exactive.HF.X.Orbitrap_6070  \
# AAAS                                                    27.351866
# AACS                                                          NaN
# AAMDC                                                   24.433071
# AAMP                                                    25.275225
# AAR2                                                    24.845894
# ...                                                           ...
# ZWILCH                                                        NaN
# ZWINT                                                         NaN
# ZYX                                                     29.726472
# hCG_2014768.TMA7                                        28.933427
# pk.ZAK                                                        NaN
#
#                   X2020_01_03_16_58_Q.Exactive.HF.X.Orbitrap_6070  \
# AAAS                                                    27.619749
# AACS                                                    25.623773
# AAMDC                                                   23.520373
# AAMP                                                    27.135553
# AAR2                                                    25.971277
# ...                                                           ...
# ZWILCH                                                  25.069482
# ZWINT                                                         NaN
# ZYX                                                     30.952062
# hCG_2014768.TMA7                                              NaN
# pk.ZAK                                                  27.086387
#
#                   X2020_01_03_20_10_Q.Exactive.HF.X.Orbitrap_6070  ...  \
# AAAS                                                    27.299813  ...
# AACS                                                          NaN  ...
# AAMDC                                                   25.660360  ...
# AAMP                                                    27.732792  ...
# AAR2                                                    26.896545  ...
# ...                                                           ...  ...
# ZWILCH                                                  24.685280  ...
# ZWINT                                                   24.662752  ...
# ZYX                                                     31.004840  ...
# hCG_2014768.TMA7                                              NaN  ...
# pk.ZAK                                                  27.080808  ...
#
#                   X2020_05_20_12_33_Q.Exactive.HF.X.Orbitrap_6070  \
# AAAS                                                    27.395910
# AACS                                                    25.551510
# AAMDC                                                         NaN
# AAMP                                                    25.740597
# AAR2                                                    25.893215
# ...                                                           ...
# ZWILCH                                                        NaN
# ZWINT                                                   25.492406
# ZYX                                                     28.276308
# hCG_2014768.TMA7                                        28.252144
# pk.ZAK                                                        NaN
#
#                   X2020_05_20_15_35_Q.Exactive.HF.X.Orbitrap_6070  \
# AAAS                                                    27.721233
# AACS                                                    24.915976
# AAMDC                                                   24.124709
# AAMP                                                    26.078081
# AAR2                                                    26.726374
# ...                                                           ...
# ZWILCH                                                        NaN
# ZWINT                                                   26.087399
# ZYX                                                     28.691057
# hCG_2014768.TMA7                                              NaN
# pk.ZAK                                                        NaN
#
#                   X2020_05_22_14_57_Q.Exactive.HF.X.Orbitrap_6070  \
# AAAS                                                    27.807533
# AACS                                                    24.713925
# AAMDC                                                         NaN
# AAMP                                                    25.856998
# AAR2                                                    25.692774
# ...                                                           ...
# ZWILCH                                                        NaN
# ZWINT                                                         NaN
# ZYX                                                     28.632182
# hCG_2014768.TMA7                                        26.563560
# pk.ZAK                                                        NaN
#
#                   X2020_05_22_17_43_Q.Exactive.HF.X.Orbitrap_6070  \
# AAAS                                                    28.051495
# AACS                                                    25.608344
# AAMDC                                                   26.030317
# AAMP                                                    26.375159
# AAR2                                                    25.536411
# ...                                                           ...
# ZWILCH                                                  22.678440
# ZWINT                                                   25.441676
# ZYX                                                     28.992129
# hCG_2014768.TMA7                                              NaN
# pk.ZAK                                                        NaN
#
#                   X2020_05_26_14_20_Q.Exactive.HF.X.Orbitrap_6070  \
# AAAS                                                    27.324573
# AACS                                                    26.800453
# AAMDC                                                   25.518603
# AAMP                                                    25.204077
# AAR2                                                    27.262844
# ...                                                           ...
# ZWILCH                                                  23.852529
# ZWINT                                                   26.853885
# ZYX                                                     29.961546
# hCG_2014768.TMA7                                              NaN
# pk.ZAK                                                        NaN
#
#                   X2020_05_27_13_57_Q.Exactive.HF.X.Orbitrap_6070  \
# AAAS                                                    29.119440
# AACS                                                    27.061470
# AAMDC                                                   25.989062
# AAMP                                                    27.998626
# AAR2                                                    28.294433
# ...                                                           ...
# ZWILCH                                                  24.652394
# ZWINT                                                   27.950714
# ZYX                                                     30.793508
# hCG_2014768.TMA7                                              NaN
# pk.ZAK                                                        NaN
#
#                   X2020_05_28_04_06_Q.Exactive.HF.X.Orbitrap_6070  \
# AAAS                                                    30.080299
# AACS                                                    27.372936
# AAMDC                                                   26.759769
# AAMP                                                    27.600879
# AAR2                                                    28.022898
# ...                                                           ...
# ZWILCH                                                  26.042078
# ZWINT                                                   28.031863
# ZYX                                                     31.340482
# hCG_2014768.TMA7                                              NaN
# pk.ZAK                                                        NaN
#
#                   X2020_06_01_10_22_Q.Exactive.HF.X.Orbitrap_6070  \
# AAAS                                                    27.298153
# AACS                                                          NaN
# AAMDC                                                   23.002336
# AAMP                                                    28.318466
# AAR2                                                          NaN
# ...                                                           ...
# ZWILCH                                                        NaN
# ZWINT                                                         NaN
# ZYX                                                     29.382862
# hCG_2014768.TMA7                                        29.336370
# pk.ZAK                                                  25.824615
#
#                   X2020_06_01_15_41_Q.Exactive.HF.X.Orbitrap_6070  \
# AAAS                                                    27.121097
# AACS                                                          NaN
# AAMDC                                                         NaN
# AAMP                                                    27.968017
# AAR2                                                    26.707146
# ...                                                           ...
# ZWILCH                                                  25.081966
# ZWINT                                                         NaN
# ZYX                                                     30.146980
# hCG_2014768.TMA7                                        29.706570
# pk.ZAK                                                  26.405258
#
#                   X2020_06_02_09_41_Q.Exactive.HF.X.Orbitrap_6070
# AAAS                                                    29.037870
# AACS                                                    25.989127
# AAMDC                                                   25.120167
# AAMP                                                    26.943690
# AAR2                                                    28.087955
# ...                                                           ...
# ZWILCH                                                        NaN
# ZWINT                                                   24.793970
# ZYX                                                     29.846835
# hCG_2014768.TMA7                                        29.212339
# pk.ZAK                                                        NaN
#
# [4535 rows x 50 columns]

# %% [markdown]
# ## Perform imputation

# %% [markdown]
# - msBayesImpute is user-friendly because it requires no parameter tunning.
# - In some cases, users would like to fix the number of latent factors or minimum explained variance, which can be set in msBayesImpute arguments by **n_components** (default is None) and **drop_factor_threshold** (default is 0.01).
# - There is also two options in **convergence_mode**: "fast" and "slow" (defualt)

# %%
# perform model training
msBayes_model = msBayesImpute()  # arguments
msBayes_model.train(df)
impute_data = msBayes_model.predict(df)
# Out:
# Model option: alternating_featureWise, convergence mode: fast, shinrakge: HorseShoe
#
# 1. Initialize dropout curve:  rho - 24.20, zeta - 1.71
# 2. Initialize training and optimize number of factors.
#   - Current factor number is: 25
#   Epoch 1: elapsed time=00:01, LOSS=4.341978
#   Epoch 100: elapsed time=00:06, deltaLOSS=0.008010 (0.18447%)
#   Epoch 200: elapsed time=00:11, deltaLOSS=0.004017 (0.09252%)
#   Epoch 300: elapsed time=00:17, deltaLOSS=0.006029 (0.13885%)
#   Epoch 400: elapsed time=00:23, deltaLOSS=0.001822 (0.04196%)
#   Epoch 500: elapsed time=00:28, deltaLOSS=-0.002411 (0.05553%)
#   Epoch 600: elapsed time=00:34, deltaLOSS=0.003870 (0.08912%)
#   Epoch 700: elapsed time=00:41, deltaLOSS=0.002123 (0.04889%)
#   - Current factor number is: 3
#   The final number is 3.
# 3. Start final model training.
#   Step 1, refine factorization model.
#   Epoch 1: elapsed time=00:50, LOSS=1.325378
#   Step 2, refine feature-wise dropout curves.
#   Epoch 100: elapsed time=00:56, deltaLOSS=0.002489 (0.67355%)
#   Epoch 200: elapsed time=00:59, deltaLOSS=-0.000208 (0.05626%)
#   Step 3, refine factorization model.
#   Epoch 300: elapsed time=01:03, deltaLOSS=0.000970 (0.02234%)
#
#   Finally, elapsed time=01:03
#
# Model training finished!

# %%
#save the results to a csv file
impute_data.to_csv('imputation_python.csv')
